# %% [markdown]
# <a href="https://colab.research.google.com/github/flydragon2018/colab_notebooks/blob/main/kaggle_gcs_data_to_gdrive_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/mydrive', force_remount=True)
# Out:
# Mounted at /content/mydrive

# %%
#ubiquant market prediction

# %%
# !pip -q install fsspec
# !pip -q install gcsfs
import gcsfs
fs = gcsfs.GCSFileSystem()

# %%
#  gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507
# test

# %%
# !gsutil -m cp -r  gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507   /content/mydrive/MyDrive
# Out:
# Copying gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/model0.pytorch...
# Copying gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/submission.csv...
# Copying gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/test600_label.csv...
# Copying gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/test/kaggle/mytmp/005b7df6a.hdf5...
# Copying gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/test/kaggle/mytmp/0153a00c9.hdf5...
# Copying gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/train_test600_label.csv...
# Copying gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/test/kaggle/mytmp/017682374.hdf5...
# Copying gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/test/kaggle/mytmp/00368b973.hdf5...
# Copying gs://kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/test/kaggle/mytmp/01bd10dc8.hdf5...
# ...

# %%
# g2 train 

# gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812

# %%
# !gsutil -m cp -r gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train   /content/mydrive/MyDrive/g2
# Out:
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/004f23b2d.hdf5...
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/001121a05.hdf5...
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/00a6db666.hdf5...
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/00f36a6ac.hdf5...
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/010a387db.hdf5...
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/0197bacf8.hdf5...
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/01b8b67f3.hdf5...
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/01bcf6533.hdf5...
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/01dba9731.hdf5...
# Copying gs://kds-c1ca6c7df87f74bb2ac6d9ead33b6ea8cd6dfef3a3ef395430343812/train/021248995.hdf5...
# ...

# %%
# !cp /content/mydrive/MyDrive/kds-b4096bfd741db5ec511b1e847f970f9ed4ed15fa80f51197bdfe3507/test/kaggle/mytmp/*.hdf5 /content/mydrive/MyDrive/g2/train/

# %%
! ls /content/mydrive/MyDrive/g2/train/ -l | wc -l
# Out:
# 1204

# %%
 # !git push -u origin master
# Out:
# fatal: not a git repository (or any of the parent directories): .git
